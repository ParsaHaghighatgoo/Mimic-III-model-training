# %%
import pandas as pd

# Parameters
input_file = "CHARTEVENTS.csv"  # Your large CSV file
chunk_size = 1_000_000  # Number of rows per chunk

# Read and split the large CSV
for i, chunk in enumerate(pd.read_csv(input_file, chunksize=chunk_size)):
    chunk.to_csv(f"chunk_{i}.csv", index=False)
    print(f"Saved chunk_{i}.csv")
# Out:
# Saved chunk_0.csv
# Saved chunk_1.csv
# Saved chunk_2.csv
